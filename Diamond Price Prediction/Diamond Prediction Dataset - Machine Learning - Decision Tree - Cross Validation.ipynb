# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("F:\Data Science\Kaggle Data Sets\Diamonds Prices2022.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [53943 rows x 10 columns]

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean       0.797935     61.749322     57.457251   3932.734294      5.731158
# std        0.473999      1.432626      2.234549   3989.338447      1.121730
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53943.000000  53943.000000
# mean       5.734526      3.538730
# std        1.142103      0.705679
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53943 non-null  float64
#  1   cut      53943 non-null  object
#  2   color    53943 non-null  object
#  3   clarity  53943 non-null  object
#  4   depth    53943 non-null  float64
#  5   table    53943 non-null  float64
#  6   price    53943 non-null  int64
#  7   x        53943 non-null  float64
#  8   y        53943 non-null  float64
#  9   z        53943 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13793
# Very Good    12083
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df['color'].value_counts()
# Out:
# G    11292
# E     9799
# F     9543
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# SI1     13067
# VS2     12259
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
corrmat = df.corr()
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corrmat,annot=True)
# Out:
# <AxesSubplot:>

# %%
def remove_outliers(df):
    q1=df.quantile(0.25)
    q3=df.quantile(0.75)
    iqr=q3-q1
    df_final=df[((df<(q1-1.5*iqr)) | (df>(q3+1.5*iqr)))]
    df_final_df=pd.DataFrame(df_final)
    return df_final_df

# %%
depth_removed_df= remove_outliers(df.depth)
depth_removed_df
# Out:
# 2        56.9
# 8        65.1
# 24       58.1
# 35       58.2
# 42       65.2
#          ...
# 53882    65.4
# 53886    58.0
# 53890    57.9
# 53895    57.8
# 53927    58.1
# Name: depth, Length: 2796, dtype: float64

# %%
def remove_df_outliers(dfc,df):
    for i in dfc.index:
        df.drop(index=i,inplace=True)
    return df

# %%
len(df)
# Out:
# 53943

# %%
def remove_df_outliers(dfc,df):
    for i in dfc.index:
        df.drop(index=i,inplace=True)
    return df

# %%
remove_df_outliers(df_carat_removed,df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [52054 rows x 10 columns]

# %%
len(df)
# Out:
# 52054

# %%
table_removed_df= remove_outliers(df.table)
table_removed_df

remove_df_outliers(table_removed_df,df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [48916 rows x 10 columns]

# %%
len(table_removed_df)
# Out:
# 342

# %%
len(df)
# Out:
# 48916

# %%
x_removed_df= remove_outliers(df.x)
x_removed_df

remove_df_outliers(x_removed_df,df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [48910 rows x 10 columns]

# %%
len(x_removed_df)
# Out:
# 6

# %%
len(df)
# Out:
# 48910

# %%
y_removed_df= remove_outliers(df.y)
y_removed_df

remove_df_outliers(y_removed_df,df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [48909 rows x 10 columns]

# %%
len(y_removed_df)
# Out:
# 1

# %%
len(df)
# Out:
# 48909

# %%
z_removed_df= remove_outliers(df.z)
z_removed_df

remove_df_outliers(z_removed_df,df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [48901 rows x 10 columns]

# %%
len(z_removed_df)
# Out:
# 8

# %%
len(df)
# Out:
# 48901

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

# %%
df['cut']=label_encoder.fit_transform(df.cut)

# %%
df['color']=label_encoder.fit_transform(df.color)
df['clarity']=label_encoder.fit_transform(df.clarity)

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24    4      6        7   62.8   57.0    336  3.94  3.96  2.48
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    3      1        2   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    3      2        2   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70    4      1        5   60.5   59.0   2757  5.71  5.76  3.47
#
# [48901 rows x 10 columns]

# %%
x=df.drop(columns='price',axis=1)
y=df.price

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

scores = cross_val_score(clf,x,y,cv=5)
scores
np.average(scores)
# Out:
# -1.931131706385625

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
clf=DecisionTreeRegressor()

scores = cross_val_score(clf,x,y,cv=5)
scores
np.average(scores)
# Out:
# -0.029320676499796815

# %%
from sklearn.model_selection import cross_val_score
import xgboost
clf=xgboost.XGBRFRegressor()

scores = cross_val_score(clf,x,y,cv=5)
scores
np.average(scores)
# Out:
# -0.13825314261717492

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=6)

scores = cross_val_score(clf,x,y,cv=5)
scores

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
clf=DecisionTreeRegressor()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
clf.score(x_test,y_test)
# Out:
# 0.9666073928627283

# %%
clf.predict([[0.24,4,6,7,62.8,57.0,3.94,3.96,2.48]])
# Out:
# C:\Users\jnoot\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([336.])
